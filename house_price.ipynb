# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv('data.csv')
df
# Out:
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0        1          60       RL         65.0     8450   Pave   NaN      Reg
# 1        2          20       RL         80.0     9600   Pave   NaN      Reg
# 2        3          60       RL         68.0    11250   Pave   NaN      IR1
# 3        4          70       RL         60.0     9550   Pave   NaN      IR1
# 4        5          60       RL         84.0    14260   Pave   NaN      IR1
# ...    ...         ...      ...          ...      ...    ...   ...      ...
# 1455  1456          60       RL         62.0     7917   Pave   NaN      Reg
# 1456  1457          20       RL         85.0    13175   Pave   NaN      Reg
# 1457  1458          70       RL         66.0     9042   Pave   NaN      Reg
# 1458  1459          20       RL         68.0     9717   Pave   NaN      Reg
# 1459  1460          20       RL         75.0     9937   Pave   NaN      Reg
#
# ...

# %% [markdown]
# # Basic Checks

# %%
df.head()
# Out:
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0   1          60       RL         65.0     8450   Pave   NaN      Reg
# 1   2          20       RL         80.0     9600   Pave   NaN      Reg
# 2   3          60       RL         68.0    11250   Pave   NaN      IR1
# 3   4          70       RL         60.0     9550   Pave   NaN      IR1
# 4   5          60       RL         84.0    14260   Pave   NaN      IR1
#
#   LandContour Utilities  ... PoolArea PoolQC Fence MiscFeature MiscVal MoSold  \
# 0         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      2
# 1         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      5
# 2         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      9
# 3         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      2
# 4         Lvl    AllPub  ...        0    NaN   NaN         NaN       0     12
#
#   YrSold  SaleType  SaleCondition  SalePrice
# ...

# %%
df.tail()
# Out:
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 1455  1456          60       RL         62.0     7917   Pave   NaN      Reg
# 1456  1457          20       RL         85.0    13175   Pave   NaN      Reg
# 1457  1458          70       RL         66.0     9042   Pave   NaN      Reg
# 1458  1459          20       RL         68.0     9717   Pave   NaN      Reg
# 1459  1460          20       RL         75.0     9937   Pave   NaN      Reg
#
#      LandContour Utilities  ... PoolArea PoolQC  Fence MiscFeature MiscVal  \
# 1455         Lvl    AllPub  ...        0    NaN    NaN         NaN       0
# 1456         Lvl    AllPub  ...        0    NaN  MnPrv         NaN       0
# 1457         Lvl    AllPub  ...        0    NaN  GdPrv        Shed    2500
# 1458         Lvl    AllPub  ...        0    NaN    NaN         NaN       0
# 1459         Lvl    AllPub  ...        0    NaN    NaN         NaN       0
#
#      MoSold YrSold  SaleType  SaleCondition  SalePrice
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1460 entries, 0 to 1459
# Data columns (total 81 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             1460 non-null   int64
#  1   MSSubClass     1460 non-null   int64
#  2   MSZoning       1460 non-null   object
#  3   LotFrontage    1201 non-null   float64
#  4   LotArea        1460 non-null   int64
#  5   Street         1460 non-null   object
#  6   Alley          91 non-null     object
#  7   LotShape       1460 non-null   object
#  8   LandContour    1460 non-null   object
#  9   Utilities      1460 non-null   object
#  10  LotConfig      1460 non-null   object
#  11  LandSlope      1460 non-null   object
#  12  Neighborhood   1460 non-null   object
#  13  Condition1     1460 non-null   object
#  14  Condition2     1460 non-null   object
#  15  BldgType       1460 non-null   object
#  16  HouseStyle     1460 non-null   object
# ...

# %%
df.describe()
# Out:
#                 Id   MSSubClass  LotFrontage        LotArea  OverallQual  \
# count  1460.000000  1460.000000  1201.000000    1460.000000  1460.000000
# mean    730.500000    56.897260    70.049958   10516.828082     6.099315
# std     421.610009    42.300571    24.284752    9981.264932     1.382997
# min       1.000000    20.000000    21.000000    1300.000000     1.000000
# 25%     365.750000    20.000000    59.000000    7553.500000     5.000000
# 50%     730.500000    50.000000    69.000000    9478.500000     6.000000
# 75%    1095.250000    70.000000    80.000000   11601.500000     7.000000
# max    1460.000000   190.000000   313.000000  215245.000000    10.000000
#
#        OverallCond    YearBuilt  YearRemodAdd   MasVnrArea   BsmtFinSF1  ...  \
# count  1460.000000  1460.000000   1460.000000  1452.000000  1460.000000  ...
# mean      5.575342  1971.267808   1984.865753   103.685262   443.639726  ...
# std       1.112799    30.202904     20.645407   181.066207   456.098091  ...
# ...

# %%
df.describe(include='O')
# Out:
#        MSZoning Street Alley LotShape LandContour Utilities LotConfig  \
# count      1460   1460    91     1460        1460      1460      1460
# unique        5      2     2        4           4         2         5
# top          RL   Pave  Grvl      Reg         Lvl    AllPub    Inside
# freq       1151   1454    50      925        1311      1459      1052
#
#        LandSlope Neighborhood Condition1  ... GarageType GarageFinish  \
# count       1460         1460       1460  ...       1379         1379
# unique         3           25          9  ...          6            3
# top          Gtl        NAmes       Norm  ...     Attchd          Unf
# freq        1382          225       1260  ...        870          605
#
#        GarageQual GarageCond PavedDrive PoolQC  Fence MiscFeature SaleType  \
# count        1379       1379       1460      7    281          54     1460
# unique          5          5          3      3      4           4        9
# ...

# %%
df.head(pd.set_option('display.max_columns',None))
# Out:
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0        1          60       RL         65.0     8450   Pave   NaN      Reg
# 1        2          20       RL         80.0     9600   Pave   NaN      Reg
# 2        3          60       RL         68.0    11250   Pave   NaN      IR1
# 3        4          70       RL         60.0     9550   Pave   NaN      IR1
# 4        5          60       RL         84.0    14260   Pave   NaN      IR1
# ...    ...         ...      ...          ...      ...    ...   ...      ...
# 1455  1456          60       RL         62.0     7917   Pave   NaN      Reg
# 1456  1457          20       RL         85.0    13175   Pave   NaN      Reg
# 1457  1458          70       RL         66.0     9042   Pave   NaN      Reg
# 1458  1459          20       RL         68.0     9717   Pave   NaN      Reg
# 1459  1460          20       RL         75.0     9937   Pave   NaN      Reg
#
# ...

# %% [markdown]
# # Exploratory data analysis

# %%
import sweetviz as sv
file=sv.analyze(df)
file.show_html()
# Out:
#                                              |                                             | [  0%]   00:00 ->…
# Report SWEETVIZ_REPORT.html was generated! NOTEBOOK/COLAB USERS: the web browser MAY not pop up, regardless, the report IS saved in your notebook/colab files.

# %%
num_col=df.select_dtypes(include = ['float64', 'int64'])
num_col
# Out:
#         Id  MSSubClass  LotFrontage  LotArea  OverallQual  OverallCond  \
# 0        1          60         65.0     8450            7            5
# 1        2          20         80.0     9600            6            8
# 2        3          60         68.0    11250            7            5
# 3        4          70         60.0     9550            7            5
# 4        5          60         84.0    14260            8            5
# ...    ...         ...          ...      ...          ...          ...
# 1455  1456          60         62.0     7917            6            5
# 1456  1457          20         85.0    13175            6            6
# 1457  1458          70         66.0     9042            7            9
# 1458  1459          20         68.0     9717            5            6
# 1459  1460          20         75.0     9937            5            6
#
#       YearBuilt  YearRemodAdd  MasVnrArea  BsmtFinSF1  BsmtFinSF2  BsmtUnfSF  \
# ...

# %% [markdown]
# # Insights from EDA

# %% [markdown]
# - MSZoning : There are more no.of Residential Low Density.Less members are choosing Residential High Density.
# - LotFrontage	: More no.of houses are connected to the street are 60-65fts.
# - LotArea : More no.of lot size are 7200-9600 and less no.of choosing 391k-215k.
# - Street : More than 99% are having pave.
# - LotShape : Most of the shape of the property are Regular and Slightly irregular.
# - LandContour : Most of the land faltness is level/flat.
# - Utilities : More than 99% are having all public facitiles.
# - LotConfig : More no.of are having inside lot and corner lot.
# - LandSlope : 95% are having Gentle slope of property.
# - Neighborhood : Neighbourhood cities are North Ames,College Creek and remaining are small cities.
# - Condition1 : 86% are normal,less percent are close to feeder street,arterial street,North-South Railroad,Near positive off-                   site feature--park, greenbelt,East-West Railroad,postive off-site feature.
# - BldgType : 84% are of single family Detached, remaining are less in number.
# - OverallQual : 50% of rating are average and above average and 40-45 precent are more happy and less rating are less in number.                ( rating for material)
# - OverallCond : 56% are rated average , 38% are rated more than above average
# - YearBuilt : More construction are done in 2000.
# - RoofStyle : Gable and Hip are 98% and remaining are <1%.
# - RoofMatl : 98% are CompShg.
# - Exterior1st : VinylSd,HdBoard,MetalSd,Wd Sdng,Plywood,CemntBd are used as  Exterior covering on house
# - ExterQual :  most of evalutation are good and average and very less are excellent.
# - ExterCond :  present condition of the material on the exterior are good and average.
# - Foundation : Most of the foundation are Poured Contrete,Cinder Block and less are Brick & Tile and Slab.
# - BsmtQual : Most of the height of  basement is (90-99 inches) and (80-89 inches).
# - BsmtCond : condition of the basement slight dampness allowed.
# - BsmtExposure : Average Exposure and No Exposure
# - BsmtFinType1 : Rating of basement finished area are Unfinshed and Good Living Quarters
# - Heating : MOst of the	Gas forced warm air furnace.
# - HeatingQC : Heating quality and condition are Excellent and Good.
# - CentralAir : 93% are having Central air conditioning.
# - Electrical : most of them are having Standard Circuit Breakers & Romex.
# - 1stFlrSF :  First Floor square feet are in between 864 and 1040 fts.
# - 2ndFlrSF : Most of them are not having second floor.
# - BsmtFullBath : most of them are having 0 and 1.
# - FullBath :  Full bathrooms above grade are 2 and 1.
# - HalfBath : Half baths above grade are 0 and 1.
# - BedroomAbvGr : Bedrooms above grade are 3 and 2.
# - KitchenAbvGr : Kitchens above grade is 1.
# - KitchenQual : Kitchen quality are average and good.
# - Functional : Home functionality is Typical Functionality.
# - Fireplaces : Number of fireplaces 0 and 1.
# - GarageType : Garage location is Attached to home.
# - GarageFinish :  Interior finish of the garage are 26% is Finished,31% is Rough Finished,43% is Unfinished.
# - GarageYrBlt : Year garage was built in between 2005 -2006.
# - GarageCars : Size of garage in car capacity mostly 2 and 1.
# - GarageQual : Garage quality is average.
# - GarageCond :Garage condition is average.
# - PavedDrive : mostly Paved .
# - WoodDeckSF : Wood deck area in square feet is than 50%
# - OpenPorchSF : very less percent are having openporch.
# - EnclosedPorch : more than 80% are not having this enclosedproch
# - ScreenPorch : more than 92% are not having this ScreenPorch.
# - MoSold : May,June,July are most sold houses.
# - YrSold : 2006-2009 are years sold.
# - SaleType : Most are Warranty Deed - Conventional type
# - SaleCondition : 82% are normal.

# %%
cat_col=df.select_dtypes(include = ['object'])
cat_col
# Out:
#      MSZoning Street Alley LotShape LandContour Utilities LotConfig LandSlope  \
# 0          RL   Pave   NaN      Reg         Lvl    AllPub    Inside       Gtl
# 1          RL   Pave   NaN      Reg         Lvl    AllPub       FR2       Gtl
# 2          RL   Pave   NaN      IR1         Lvl    AllPub    Inside       Gtl
# 3          RL   Pave   NaN      IR1         Lvl    AllPub    Corner       Gtl
# 4          RL   Pave   NaN      IR1         Lvl    AllPub       FR2       Gtl
# ...       ...    ...   ...      ...         ...       ...       ...       ...
# 1455       RL   Pave   NaN      Reg         Lvl    AllPub    Inside       Gtl
# 1456       RL   Pave   NaN      Reg         Lvl    AllPub    Inside       Gtl
# 1457       RL   Pave   NaN      Reg         Lvl    AllPub    Inside       Gtl
# 1458       RL   Pave   NaN      Reg         Lvl    AllPub    Inside       Gtl
# 1459       RL   Pave   NaN      Reg         Lvl    AllPub    Inside       Gtl
#
# ...

# %% [markdown]
# # Drop the columns

# %%
df.drop(['PoolQC','Fence','MiscFeature','Alley','FireplaceQu','Id'],axis=1,inplace=True)
df
# Out:
#       MSSubClass MSZoning  LotFrontage  LotArea Street LotShape LandContour  \
# 0             60       RL         65.0     8450   Pave      Reg         Lvl
# 1             20       RL         80.0     9600   Pave      Reg         Lvl
# 2             60       RL         68.0    11250   Pave      IR1         Lvl
# 3             70       RL         60.0     9550   Pave      IR1         Lvl
# 4             60       RL         84.0    14260   Pave      IR1         Lvl
# ...          ...      ...          ...      ...    ...      ...         ...
# 1455          60       RL         62.0     7917   Pave      Reg         Lvl
# 1456          20       RL         85.0    13175   Pave      Reg         Lvl
# 1457          70       RL         66.0     9042   Pave      Reg         Lvl
# 1458          20       RL         68.0     9717   Pave      Reg         Lvl
# 1459          20       RL         75.0     9937   Pave      Reg         Lvl
#
# ...

# %% [markdown]
# - Droping the columns which as more null values

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1460 entries, 0 to 1459
# Data columns (total 75 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   MSSubClass     1460 non-null   int64
#  1   MSZoning       1460 non-null   object
#  2   LotFrontage    1201 non-null   float64
#  3   LotArea        1460 non-null   int64
#  4   Street         1460 non-null   object
#  5   LotShape       1460 non-null   object
#  6   LandContour    1460 non-null   object
#  7   Utilities      1460 non-null   object
#  8   LotConfig      1460 non-null   object
#  9   LandSlope      1460 non-null   object
#  10  Neighborhood   1460 non-null   object
#  11  Condition1     1460 non-null   object
#  12  Condition2     1460 non-null   object
#  13  BldgType       1460 non-null   object
#  14  HouseStyle     1460 non-null   object
#  15  OverallQual    1460 non-null   int64
#  16  OverallCond    1460 non-null   int64
# ...

# %% [markdown]
# # Fixing null values

# %%
df.loc[df['LotFrontage'].isnull()==True,'LotFrontage']=df.LotFrontage.mean()

# %%
df.loc[df['MasVnrType'].isnull()==True,'MasVnrType']='None'

# %%
df.loc[df['MasVnrArea'].isnull()==True,'MasVnrArea']=df.MasVnrArea.median()

# %%
df.loc[df['BsmtQual'].isnull()==True,'BsmtQual']='TA'

# %%
df.loc[df['BsmtCond'].isnull()==True,'BsmtCond']='TA'

# %%
df.loc[df['BsmtExposure'].isnull()==True,'BsmtExposure']='No'

# %%
df.loc[df['BsmtFinType1'].isnull()==True,'BsmtFinType1']='Unf'

# %%
df.loc[df['BsmtFinType2'].isnull()==True,'BsmtFinType2']='Unf'

# %%
df.loc[df['Electrical'].isnull()==True,'Electrical']='SBrkr'

# %%
df.loc[df['GarageType'].isnull()==True,'GarageType']='Attchd'

# %%
df.loc[df['GarageYrBlt'].isnull()==True,'GarageYrBlt']=df.GarageYrBlt.mean()

# %%
df.loc[df['GarageFinish'].isnull()==True,'GarageFinish']='Unf'

# %%
df.loc[df['GarageQual'].isnull()==True,'GarageQual']='TA'

# %%
df.loc[df['GarageCond'].isnull()==True,'GarageCond']='TA'

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1460 entries, 0 to 1459
# Data columns (total 75 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   MSSubClass     1460 non-null   int64
#  1   MSZoning       1460 non-null   object
#  2   LotFrontage    1460 non-null   float64
#  3   LotArea        1460 non-null   int64
#  4   Street         1460 non-null   object
#  5   LotShape       1460 non-null   object
#  6   LandContour    1460 non-null   object
#  7   Utilities      1460 non-null   object
#  8   LotConfig      1460 non-null   object
#  9   LandSlope      1460 non-null   object
#  10  Neighborhood   1460 non-null   object
#  11  Condition1     1460 non-null   object
#  12  Condition2     1460 non-null   object
#  13  BldgType       1460 non-null   object
#  14  HouseStyle     1460 non-null   object
#  15  OverallQual    1460 non-null   int64
#  16  OverallCond    1460 non-null   int64
# ...

# %% [markdown]
# - Fixed the null values which has less in numbers
#   - The columns which are int and float used mean and median to fix.
#   - The columns which are string fixed with mode.

# %% [markdown]
# # Detecting the outliers

# %%
numerical_features =df.select_dtypes(include=['number'])

num_features = len(numerical_features.columns)
num_rows = 8  # Set the number of rows
num_cols = 5  # Set the number of columns
fig, axes = plt.subplots(nrows=num_rows, ncols=num_cols, figsize=(15, 40))
axes = axes.flatten()

for i, column in enumerate(numerical_features.columns):
    if i < num_features:
        sns.boxplot(x=df[column], ax=axes[i])
        axes[i].set_title(f'Box Plot for {column}')

for i in range(len(numerical_features.columns), len(axes)):
    fig.delaxes(axes[i])
    
plt.tight_layout()
plt.show()

# %%
def handle_outliers_iqr(dataframe, column):
    Q1 = dataframe[column].quantile(0.25)
    Q3 = dataframe[column].quantile(0.75)
    IQR = Q3 - Q1
    lower = Q1 - 1.5 * IQR
    upper = Q3 + 1.5 * IQR
    outliers = dataframe[(dataframe[column] < lower) | (dataframe[column] > upper)]
    dataframe.loc[(dataframe[col]>upper,col)]=upper
    dataframe.loc[(dataframe[col]<lower,col)]=lower 
    
    return dataframe


for col in df.select_dtypes(include=["number"]).columns :
    houses = handle_outliers_iqr(df, col)

# %%
print("this plot show the outoutliers in each column After delete them")

numerical_features = df.select_dtypes(include=['number'])
num_features = len(numerical_features.columns)
num_rows = 8  # Set the number of rows
num_cols =5 # Set the number of columns


fig, axes = plt.subplots(nrows=num_rows, ncols=num_cols, figsize=(15, 40))


axes = axes.flatten()

for i, column in enumerate(numerical_features.columns):
    if i < num_features:
        sns.boxplot(x=df[column], ax=axes[i])
        axes[i].set_title(f'Box Plot for {column}')

for i in range(len(numerical_features.columns), len(axes)):
    fig.delaxes(axes[i])
    
plt.tight_layout()

plt.show()
# Out:
# this plot show the outoutliers in each column After delete them

# %% [markdown]
# - Fixed the outliers using IQR method

# %% [markdown]
# # Label encoding

# %%
obj_col = df.select_dtypes(include=['object']).columns
obj_col
# Out:
# Index(['MSZoning', 'Street', 'LotShape', 'LandContour', 'Utilities',
#        'LotConfig', 'LandSlope', 'Neighborhood', 'Condition1', 'Condition2',
#        'BldgType', 'HouseStyle', 'RoofStyle', 'RoofMatl', 'Exterior1st',
#        'Exterior2nd', 'MasVnrType', 'ExterQual', 'ExterCond', 'Foundation',
#        'BsmtQual', 'BsmtCond', 'BsmtExposure', 'BsmtFinType1', 'BsmtFinType2',
#        'Heating', 'HeatingQC', 'CentralAir', 'Electrical', 'KitchenQual',
#        'Functional', 'GarageType', 'GarageFinish', 'GarageQual', 'GarageCond',
#        'PavedDrive', 'SaleType', 'SaleCondition'],
#       dtype='object')

# %%
from sklearn.preprocessing import LabelEncoder
encoder = LabelEncoder()
for col in obj_col.values.flatten():
    df[col]= encoder.fit_transform(df[col])

# %%
df
# Out:
#       MSSubClass  MSZoning  LotFrontage  LotArea  Street  LotShape  \
# 0             60         3         65.0   8450.0       1         3
# 1             20         3         80.0   9600.0       1         3
# 2             60         3         68.0  11250.0       1         0
# 3             70         3         60.0   9550.0       1         0
# 4             60         3         84.0  14260.0       1         0
# ...          ...       ...          ...      ...     ...       ...
# 1455          60         3         62.0   7917.0       1         3
# 1456          20         3         85.0  13175.0       1         3
# 1457          70         3         66.0   9042.0       1         3
# 1458          20         3         68.0   9717.0       1         3
# 1459          20         3         75.0   9937.0       1         3
#
#       LandContour  Utilities  LotConfig  LandSlope  Neighborhood  Condition1  \
# 0               3          0          4          0             5           2
# ...

# %% [markdown]
# - Changing the categorical features to integers by using Label Encoding

# %%
df.duplicated().sum()
# Out:
# 0

# %% [markdown]
# # Scaling

# %%
from sklearn.preprocessing import StandardScaler
scale=StandardScaler()
df[['MSSubClass','LotFrontage','LotArea','YearBuilt','YearRemodAdd','MasVnrArea','BsmtFinSF1','BsmtFinSF2','BsmtUnfSF','TotalBsmtSF','1stFlrSF','2ndFlrSF','LowQualFinSF','GrLivArea','TotRmsAbvGrd','GarageYrBlt','GarageArea','WoodDeckSF','OpenPorchSF','EnclosedPorch','3SsnPorch','ScreenPorch','MiscVal','MoSold','YrSold','SalePrice']]=scale.fit_transform(df[['MSSubClass','LotFrontage','LotArea','YearBuilt','YearRemodAdd','MasVnrArea','BsmtFinSF1','BsmtFinSF2','BsmtUnfSF','TotalBsmtSF','1stFlrSF','2ndFlrSF','LowQualFinSF','GrLivArea','TotRmsAbvGrd','GarageYrBlt','GarageArea','WoodDeckSF','OpenPorchSF','EnclosedPorch','3SsnPorch','ScreenPorch','MiscVal','MoSold','YrSold','SalePrice']])

# %% [markdown]
# - Scale the values using StandardScaler

# %% [markdown]
# # Correlation

# %%
corr_n =num_col.corr()

plt.figure(figsize=(30,20), dpi=200)

sns.heatmap(corr_n, cmap="Blues",annot=True)
# Out:
# <Axes: >

# %%
cr=num_col.corr()
correlation=cr["SalePrice"].sort_values(ascending=False).reset_index()
print(correlation.shape)
correlation
# Out:
# (38, 2)
#             index  SalePrice
# 0       SalePrice   1.000000
# 1     OverallQual   0.790982
# 2       GrLivArea   0.708624
# 3      GarageCars   0.640409
# 4      GarageArea   0.623431
# 5     TotalBsmtSF   0.613581
# 6        1stFlrSF   0.605852
# 7        FullBath   0.560664
# 8    TotRmsAbvGrd   0.533723
# 9       YearBuilt   0.522897
# 10   YearRemodAdd   0.507101
# 11    GarageYrBlt   0.486362
# 12     MasVnrArea   0.477493
# 13     Fireplaces   0.466929
# 14     BsmtFinSF1   0.386420
# 15    LotFrontage   0.351799
# 16     WoodDeckSF   0.324413
# 17       2ndFlrSF   0.319334
# 18    OpenPorchSF   0.315856
# 19       HalfBath   0.284108
# 20        LotArea   0.263843
# 21   BsmtFullBath   0.227122
# 22      BsmtUnfSF   0.214479
# 23   BedroomAbvGr   0.168213
# 24    ScreenPorch   0.111447
# 25       PoolArea   0.092404
# 26         MoSold   0.046432
# 27      3SsnPorch   0.044584
# 28     BsmtFinSF2  -0.011378
# 29   BsmtHalfBath  -0.016844
# ...

# %%
df.drop(['PoolArea','MoSold','3SsnPorch','BsmtFinSF2','BsmtHalfBath','LowQualFinSF','YrSold','OverallCond','MSSubClass'],axis=1,inplace=True)
df
# Out:
#       MSZoning  LotFrontage   LotArea  Street  LotShape  LandContour  \
# 0            3    -0.248215 -0.333244       1         3            3
# 1            3     0.622375 -0.013189       1         3            3
# 2            3    -0.074097  0.446022       1         0            3
# 3            3    -0.538412 -0.027104       1         0            3
# 4            3     0.854532  1.283733       1         0            3
# ...        ...          ...       ...     ...       ...          ...
# 1455         3    -0.422333 -0.481583       1         3            3
# 1456         3     0.912571  0.981767       1         3            3
# 1457         3    -0.190176 -0.168485       1         3            3
# 1458         3    -0.074097  0.019374       1         3            3
# 1459         3     0.332178  0.080602       1         3            3
#
#       Utilities  LotConfig  LandSlope  Neighborhood  Condition1  Condition2  \
# ...

# %% [markdown]
# - Finded the correlation between numericals columns and droped the low correlated columns

# %% [markdown]
# # Model Creation

# %%
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_absolute_error,mean_squared_error,r2_score
from sklearn.model_selection import cross_val_score, KFold, train_test_split

# %%
X = df.iloc[:, :-1].values
y = df.iloc[:, -1:].values

# split data to train_test_split 
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.25, random_state = 42)

# %% [markdown]
# # LINEAR REGRESSOR

# %%
model = LinearRegression()
model.fit(X_train, y_train)

y_pred = model.predict(X_test)

# %%
print(f"train score: {model.score(X_train, y_train)}")
# score for test 
print(f"test score: {model.score(X_test, y_test)}")
# Out:
# train score: 0.8913013234247475
# test score: 0.8918896572037984

# %%
mae = mean_absolute_error(y_test, y_pred)
mse = mean_squared_error(y_test, y_pred)
rmse = mean_squared_error(y_test, y_pred, squared=False)  # RMSE is the square root of MSE
print(f"\nMean Absolute Error: {mae}")
print(f"Mean Squared Error: {mse}")
print(f"Root Mean Squared Error: {rmse}")
# Out:
# Mean Absolute Error: 0.24759171691137136
# Mean Squared Error: 0.11253217891807957
# Root Mean Squared Error: 0.33545816269406764

# %%
r2 = r2_score(y_test, y_pred)
print(f"Coefficient of Determination (R^2): {r2}")
# Out:
# Coefficient of Determination (R^2): 0.8918896572037984

# %% [markdown]
# # ---------------------------------------------------------------------------------------------------------------

# %% [markdown]
# # RANDOM FOREST REGRESOR

# %%
from sklearn.ensemble import RandomForestRegressor
R_model = RandomForestRegressor()
R_model.fit(X_train,y_train)
# Out:
# C:\Users\Sowmya\AppData\Local\Temp\ipykernel_8912\910948566.py:3: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   R_model.fit(X_train,y_train)
# RandomForestRegressor()

# %%
r_ypred=R_model.predict(X_test)

# %%
print(f"Mean Absolute Error: {mean_absolute_error(y_test,r_ypred)}")
print(f"Mean Squared Error: {mean_squared_error(y_test,r_ypred)}")
print(f"Root Mean Squared Error: {np.sqrt(mean_squared_error(y_test,r_ypred))}")
print(f"R2 Score: {r2_score(y_test,r_ypred)}")
# Out:
# Mean Absolute Error: 0.2177991988562876
# Mean Squared Error: 0.09082911087892882
# Root Mean Squared Error: 0.3013786835178109
# R2 Score: 0.9127399255270479

# %% [markdown]
# # ---------------------------------------------------------------------------------------------------------------

# %% [markdown]
# # XGB REGRESSOR

# %%
from xgboost import XGBRegressor
X_model=XGBRegressor()
X_model.fit(X_train,y_train)
# Out:
# XGBRegressor(base_score=None, booster=None, callbacks=None,
#              colsample_bylevel=None, colsample_bynode=None,
#              colsample_bytree=None, device=None, early_stopping_rounds=None,
#              enable_categorical=False, eval_metric=None, feature_types=None,
#              gamma=None, grow_policy=None, importance_type=None,
#              interaction_constraints=None, learning_rate=None, max_bin=None,
#              max_cat_threshold=None, max_cat_to_onehot=None,
#              max_delta_step=None, max_depth=None, max_leaves=None,
#              min_child_weight=None, missing=nan, monotone_constraints=None,
#              multi_strategy=None, n_estimators=None, n_jobs=None,
#              num_parallel_tree=None, random_state=None, ...)

# %%
X_ypred=X_model.predict(X_test)

# %%
print(f"Mean Absolute Error: {mean_absolute_error(y_test,X_ypred)}")
print(f"Mean Squared Error: {mean_squared_error(y_test,X_ypred)}")
print(f"Root Mean Squared Error: {np.sqrt(mean_squared_error(y_test,X_ypred))}")
print(f"R2 Score: {r2_score(y_test,X_ypred)}")
# Out:
# Mean Absolute Error: 0.23378892629864126
# Mean Squared Error: 0.11134029507304498
# Root Mean Squared Error: 0.3336769321859768
# R2 Score: 0.8930347072001532

# %% [markdown]
# # ---------------------------------------------------------------------------------------------------------------

# %% [markdown]
# # GRADIENT BOOSTING

# %%
from sklearn.ensemble import GradientBoostingRegressor
G_model=GradientBoostingRegressor()
G_model.fit(X_train,y_train)
# Out:
# C:\Users\Sowmya\anaconda3\Lib\site-packages\sklearn\ensemble\_gb.py:437: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# GradientBoostingRegressor()

# %%
G_ypred=G_model.predict(X_test)

# %%
print(f"Mean Absolute Error: {mean_absolute_error(y_test,G_ypred)}")
print(f"Mean Squared Error: {mean_squared_error(y_test,G_ypred)}")
print(f"Root Mean Squared Error: {np.sqrt(mean_squared_error(y_test,G_ypred))}")
print(f"R2 Score: {r2_score(y_test,G_ypred)}")
# Out:
# Mean Absolute Error: 0.21866796618245402
# Mean Squared Error: 0.0900301702738808
# Root Mean Squared Error: 0.30005027957640834
# R2 Score: 0.9135074725835074

# %%
Conducted detailed analysis on 1460 records and 81 features which specifies the every detailed in house.
Tools used are python,matplotlib,pandas,sklearn.
Examined the every individual detailed in house to buy the house.
Applied many model on the dataset to get the accurate results.
