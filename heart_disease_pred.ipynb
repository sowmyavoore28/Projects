# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df1 = pd.read_csv('values.csv')
df2 = pd.read_csv('labels.csv')

# %% [markdown]
# # MERGING TWO FILES

# %%
df= pd.merge(df1, df2,how='left')
df
# Out:
#     patient_id  slope_of_peak_exercise_st_segment               thal  \
# 0       0z64un                                  1             normal
# 1       ryoo3j                                  2             normal
# 2       yt1s1x                                  1             normal
# 3       l2xjde                                  1  reversible_defect
# 4       oyt4ek                                  3  reversible_defect
# ..         ...                                ...                ...
# 175     5qfar3                                  2  reversible_defect
# 176     2s2b1f                                  2             normal
# 177     nsd00i                                  2  reversible_defect
# 178     0xw93k                                  1             normal
# 179     2nx10r                                  1             normal
#
#      resting_blood_pressure  chest_pain_type  num_major_vessels  \
# 0                       128                2                  0
# ...

# %% [markdown]
# # BASIC CHECKS

# %%
df.head()
# Out:
#   patient_id  slope_of_peak_exercise_st_segment               thal  \
# 0     0z64un                                  1             normal
# 1     ryoo3j                                  2             normal
# 2     yt1s1x                                  1             normal
# 3     l2xjde                                  1  reversible_defect
# 4     oyt4ek                                  3  reversible_defect
#
#    resting_blood_pressure  chest_pain_type  num_major_vessels  \
# 0                     128                2                  0
# 1                     110                3                  0
# 2                     125                4                  3
# 3                     152                4                  0
# 4                     178                1                  0
#
#    fasting_blood_sugar_gt_120_mg_per_dl  resting_ekg_results  \
# 0                                     0                    2
# 1                                     0                    0
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 180 entries, 0 to 179
# Data columns (total 15 columns):
#  #   Column                                Non-Null Count  Dtype
# ---  ------                                --------------  -----
#  0   patient_id                            180 non-null    object
#  1   slope_of_peak_exercise_st_segment     180 non-null    int64
#  2   thal                                  180 non-null    object
#  3   resting_blood_pressure                180 non-null    int64
#  4   chest_pain_type                       180 non-null    int64
#  5   num_major_vessels                     180 non-null    int64
#  6   fasting_blood_sugar_gt_120_mg_per_dl  180 non-null    int64
#  7   resting_ekg_results                   180 non-null    int64
#  8   serum_cholesterol_mg_per_dl           180 non-null    int64
#  9   oldpeak_eq_st_depression              180 non-null    float64
#  10  sex                                   180 non-null    int64
# ...

# %%
df.describe()
# Out:
#        slope_of_peak_exercise_st_segment  resting_blood_pressure  \
# count                         180.000000              180.000000
# mean                            1.550000              131.311111
# std                             0.618838               17.010443
# min                             1.000000               94.000000
# 25%                             1.000000              120.000000
# 50%                             1.000000              130.000000
# 75%                             2.000000              140.000000
# max                             3.000000              180.000000
#
#        chest_pain_type  num_major_vessels  \
# count       180.000000         180.000000
# mean          3.155556           0.694444
# std           0.938454           0.969347
# min           1.000000           0.000000
# 25%           3.000000           0.000000
# 50%           3.000000           0.000000
# 75%           4.000000           1.000000
# ...

# %%
df.describe(include='O')
# Out:
#        patient_id    thal
# count         180     180
# unique        180       3
# top        0z64un  normal
# freq            1      98

# %%
df.thal.unique() # shows distinct values
# Out:
# array(['normal', 'reversible_defect', 'fixed_defect'], dtype=object)

# %%
df.thal.value_counts() # shows the count of the values in a colunm
# Out:
# normal               98
# reversible_defect    74
# fixed_defect          8
# Name: thal, dtype: int64

# %%
df.heart_disease_present.value_counts()
# Out:
# 0    100
# 1     80
# Name: heart_disease_present, dtype: int64

# %% [markdown]
# # Exploratory data analysis

# %%
import sweetviz as sv
file=sv.analyze(df)
file.show_html()
# Out:
#                                              |                                             | [  0%]   00:00 ->…
# Report SWEETVIZ_REPORT.html was generated! NOTEBOOK/COLAB USERS: the web browser MAY not pop up, regardless, the report IS saved in your notebook/colab files.

# %% [markdown]
# - slope_of_peak_exercise_st_segment      : 2 indicates unhealthy heart ,1 indicates healthy heart ,0 indicates better heart with                                             exercise.
#                                             - 52% people are having healthy heart.
#                                             - 42% people are having unhealthy heart.
#                                             - 7% people having better heart rate.
# - resting_blood_pressure                 : Blood pessure rate at rest. mostly people are having greater than 120
# - chest_pain_type                        : 1 indicates typical angina,2 indicates atypical angina,3 indicates non-angina pain,4                                            indicates asymptomatic.asymptomatic are 46%,non-angina are  32%,atypical angina are                                              16% and typical angina are 7%.
#
# - num_major_vessels                      : number of major vessels (0-3) colored by flourosopy .Majorly having 0
# - fasting_blood_sugar_gt_120_mg_per_dl   : fasting blood sugar > 120 mg/dl is major.
# - resting_ekg_results	                 : resting electrocardiographic results 0 means normal,1 means ST_T wave abnormal,2                                                means left ventricaular hypertrophy .Most occured are 0 and 2.
# - serum_cholesterol_mg_per_dl            : the serum cholesterol in mg/dl (unit)
# - oldpeak_eq_st_depression	             : ST depression induced by exercise relative to rest mostly 0.
# - sex                                    : 69% male are effected.
# - age                                    : mostly 50 -65 aged people are effected.
# - max_heart_rate_achieved                :  the max heart rate achieved by an individual
# - exercise_induced_angina                : 0 is 68%,1 is 32%
# - thal                                   : 0 = normal,1 = fixed defect,2 = reversible defect majority is normal and very less                                              percent is fixed defect.

# %%
num_col=df.select_dtypes(include = ['float64', 'int64'])
num_col
# Out:
#      slope_of_peak_exercise_st_segment  resting_blood_pressure  \
# 0                                    1                     128
# 1                                    2                     110
# 2                                    1                     125
# 3                                    1                     152
# 4                                    3                     178
# ..                                 ...                     ...
# 175                                  2                     125
# 176                                  2                     180
# 177                                  2                     125
# 178                                  1                     124
# 179                                  1                     160
#
#      chest_pain_type  num_major_vessels  fasting_blood_sugar_gt_120_mg_per_dl  \
# 0                  2                  0                                     0
# ...

# %% [markdown]
# # LABEL ENCODING

# %%
from sklearn.preprocessing import LabelEncoder
encoder = LabelEncoder()
df['thal']= encoder.fit_transform(df['thal'])
df
# Out:
#     patient_id  slope_of_peak_exercise_st_segment  thal  \
# 0       0z64un                                  1     1
# 1       ryoo3j                                  2     1
# 2       yt1s1x                                  1     1
# 3       l2xjde                                  1     2
# 4       oyt4ek                                  3     2
# ..         ...                                ...   ...
# 175     5qfar3                                  2     2
# 176     2s2b1f                                  2     1
# 177     nsd00i                                  2     2
# 178     0xw93k                                  1     1
# 179     2nx10r                                  1     1
#
#      resting_blood_pressure  chest_pain_type  num_major_vessels  \
# 0                       128                2                  0
# 1                       110                3                  0
# 2                       125                4                  3
# ...

# %% [markdown]
# # DROPING THE COLUMN

# %%
df.drop('patient_id',axis=1,inplace=True)

# %%
df
# Out:
#      slope_of_peak_exercise_st_segment  thal  resting_blood_pressure  \
# 0                                    1     1                     128
# 1                                    2     1                     110
# 2                                    1     1                     125
# 3                                    1     2                     152
# 4                                    3     2                     178
# ..                                 ...   ...                     ...
# 175                                  2     2                     125
# 176                                  2     1                     180
# 177                                  2     2                     125
# 178                                  1     1                     124
# 179                                  1     1                     160
#
#      chest_pain_type  num_major_vessels  fasting_blood_sugar_gt_120_mg_per_dl  \
# ...

# %% [markdown]
# # SCALING

# %%
from sklearn.preprocessing import StandardScaler
scale=StandardScaler()
df[['resting_blood_pressure','serum_cholesterol_mg_per_dl','age','max_heart_rate_achieved']]=scale.fit_transform(df[['resting_blood_pressure','serum_cholesterol_mg_per_dl','age','max_heart_rate_achieved']])

# %% [markdown]
# # CORRELATION

# %%
corr_n =num_col.corr()

plt.figure(figsize=(20,10), dpi=200)

sns.heatmap(corr_n, cmap="Blues",annot=True)
# Out:
# <Axes: >

# %%
cr=num_col.corr()
correlation=cr["heart_disease_present"].sort_values(ascending=False).reset_index()
print(correlation.shape)
correlation
# Out:
# (13, 2)
#                                    index  heart_disease_present
# 0                  heart_disease_present               1.000000
# 1                exercise_induced_angina               0.448647
# 2                      num_major_vessels               0.421519
# 3                        chest_pain_type               0.412829
# 4               oldpeak_eq_st_depression               0.382930
# 5      slope_of_peak_exercise_st_segment               0.344224
# 6                                    sex               0.335421
# 7                    resting_ekg_results               0.145933
# 8                                    age               0.138255
# 9            serum_cholesterol_mg_per_dl               0.079775
# 10                resting_blood_pressure               0.078506
# 11  fasting_blood_sugar_gt_120_mg_per_dl               0.003379
# 12               max_heart_rate_achieved              -0.375352

# %%
df.drop(['fasting_blood_sugar_gt_120_mg_per_dl'],axis=1,inplace=True)

# %% [markdown]
# - droped the low correlated colunm

# %% [markdown]
# # MODEL CREATION

# %%
x=df.iloc[:,:-1]
y=df.heart_disease_present

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=5)

# %% [markdown]
# # SVC

# %%
from sklearn.svm import SVC
model=SVC()
model.fit(x_train,y_train)
# Out:
# SVC()

# %%
y_pred=model.predict(x_test)

# %%
from sklearn.metrics import accuracy_score,classification_report,confusion_matrix
acc=accuracy_score(y_pred,y_test)
acc
# Out:
# 0.8333333333333334

# %%
print(classification_report(y_pred,y_test))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.84      0.91      0.87        23
#            1       0.82      0.69      0.75        13
#
#     accuracy                           0.83        36
#    macro avg       0.83      0.80      0.81        36
# weighted avg       0.83      0.83      0.83        36

# %% [markdown]
# # HYPERPARAMETER TUNING

# %%
from sklearn.model_selection import GridSearchCV
  
# defining parameter range
param_grid = {'C': [1,10,100], 
              'gamma': [  1, 0.01, 0.0001],
             'kernel':['rbf','linear']} 
model=SVC()
grid = GridSearchCV(model, param_grid,refit = True, verbose =2)
  
# fitting the model for grid search
grid.fit(x,y)
# Out:
# Fitting 5 folds for each of 18 candidates, totalling 90 fits
# [CV] END ...........................C=1, gamma=1, kernel=rbf; total time=   0.0s
# [CV] END ...........................C=1, gamma=1, kernel=rbf; total time=   0.0s
# [CV] END ...........................C=1, gamma=1, kernel=rbf; total time=   0.0s
# [CV] END ...........................C=1, gamma=1, kernel=rbf; total time=   0.0s
# [CV] END ...........................C=1, gamma=1, kernel=rbf; total time=   0.0s
# [CV] END ........................C=1, gamma=1, kernel=linear; total time=   0.0s
# [CV] END ........................C=1, gamma=1, kernel=linear; total time=   0.0s
# [CV] END ........................C=1, gamma=1, kernel=linear; total time=   0.0s
# [CV] END ........................C=1, gamma=1, kernel=linear; total time=   0.0s
# [CV] END ........................C=1, gamma=1, kernel=linear; total time=   0.0s
# [CV] END ........................C=1, gamma=0.01, kernel=rbf; total time=   0.0s
# ...

# %%
grid.best_params_
# Out:
# {'C': 100, 'gamma': 0.0001, 'kernel': 'rbf'}

# %%
Smodel=SVC(kernel='rbf',gamma=0.0001,C=100)
Smodel.fit(x_train,y_train)
# Out:
# SVC(C=100, gamma=0.0001)

# %%
y_model=Smodel.predict(x_test)

# %%
print(classification_report(y_test,y_model))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.92      0.92      0.92        25
#            1       0.82      0.82      0.82        11
#
#     accuracy                           0.89        36
#    macro avg       0.87      0.87      0.87        36
# weighted avg       0.89      0.89      0.89        36

# %%
acc1=accuracy_score(y_test,y_model)
acc1
# Out:
# 0.8888888888888888

# %%
confusion_matrix(y_test,y_model)
# Out:
# array([[23,  2],
#        [ 2,  9]], dtype=int64)

# %% [markdown]
# # Conclusion

# %% [markdown]
# Analysed the effected persons with the heart disease through some of the features like sugar level, blood pressure,type of pain etc.
# Utilized toolkit including python,pandas,sklearn.
# Here we used SVC model to get best accuracy.Here it classifying very well in heart disease prediction.
# Majority people with in the age of 50-60 are having the disease and mostly males are effected.
